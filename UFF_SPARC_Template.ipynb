# %% [markdown]
# # QSOL UFF v4 notebook template
#
# This notebook loads a validated SPARC-style curve, fits the default model set, and inspects a separate SMBH/LQG scale report. See `docs/MODELS.md` before interpreting the result.

# %%
from pathlib import Path
import pandas as pd
from uff import GalaxyData, ModelOptions, build_model, fit_models
from uff.fitting import comparison_records
from uff.diagnostics import plot_model_comparison

data = GalaxyData.from_csv("DEMO_GALAXY.csv", name="DEMO_GALAXY")
data.n_points, data.metadata

# %%
names = ["nfw", "burkert", "mond-rar", "uff-empirical"]
options = ModelOptions()
models = [build_model(name, data, options) for name in names]
results = fit_models(models, data, restarts=12, random_state=42)
pd.DataFrame(comparison_records(results))

# %%
output = Path("outputs")
output.mkdir(exist_ok=True)
plot_model_comparison(data, models, results, output / "notebook_model_comparison.png")
output / "notebook_model_comparison.png"

# %% [markdown]
# ## Compact-object scale report
#
# This calculation is deliberately separate from the galaxy likelihood.

# %%
from uff.compact import compact_object_report

compact_object_report(4.3e6, dimensionless_spin=0.5, velocity_dispersion_kms=100.0)
